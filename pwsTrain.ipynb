# %% [markdown]
# ### First, See how it fares when you using pretrained weights

# %%
# !python train.py --img 640 --batch 16 --epochs 3 --data planktonTrainVal.yaml --weights yolov3.pt --nosave --cache
# Out:
# ^C
